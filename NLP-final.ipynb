# %%
import pandas as pd
import glob

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
path = './Articles'
files = glob.glob(path+'/*.csv')

li = []

for file in files:
    df = pd.read_csv(file, index_col=None, header=0)
    li.append(df)

data = pd.concat(li, axis=0, ignore_index=True)
data = data.drop(data.columns[0], axis=1)

# %%
data.sample(10)
# Out:
#             id                                              title  \
# 61591   170138  Wildfires And High Temperatures Scorch The Wes...
# 109354  100158   All The Looks At The MTV Movie & TV Awards Re...
# 64387   173613  Google Fiber Won’t Accept Any New Cities For I...
# 91682   216923  ISIS video shows how the group has turned car ...
# 96325    78376  \nTrack of the Day: ‘Jack and Diane’ by John M...
# 68383   180806  North Korea displays apparently new missiles a...
# 72574   188319  U.S. Treasury readies new tax rules as G20 vow...
# 9641     28377  Report: Caitlyn Jenner Feels ’Liberated’ after...
# 113315  112124   Hundreds Of Snow Leopards Are Being Killed Ev...
# 34359    53798  Funeral home refused to cremate gay man, lawsu...
#
#             publication                          author        date    year  \
# 61591               NPR                Camila Domonoske  2016-06-21  2016.0
# 109354    Buzzfeed News               Whitney Jefferson  2017-05-08  2017.0
# 64387               NPR                   Alina Selyukh  2016-10-26  2016.0
# 91682   Washington Post             Thomas Gibbons-Neff  2016-11-15  2016.0
# 96325          Atlantic                  Chris Bodenner  2016-11-10  2016.0
# 68383           Reuters  Sue-Lin Wong and James Pearson  2017-04-15  2017.0
# 72574           Reuters                    David Lawder  2016-04-16  2016.0
# 9641          Breitbart                 Daniel Nussbaum  2017-04-10  2017.0
# 113315    Buzzfeed News             Rose Troup Buchanan  2016-10-21  2016.0
# 34359               CNN              Emanuella Grinberg  2017-05-03  2017.0
#
#         month                                                url  \
# 61591     6.0  http://www.npr.org/sections/thetwo-way/2016/06...
# 109354    5.0  https://web.archive.org/web/20170508055955/htt...
# 64387    10.0  http://www.npr.org/sections/alltechconsidered/...
# 91682    11.0  https://web.archive.org/web/20161116002931/htt...
# 96325    11.0                                                NaN
# 68383     4.0  http://www.reuters.com/article/us-northkorea-u...
# 72574     4.0  http://www.reuters.com/article/us-imf-g20-usa-...
# 9641      4.0                                                NaN
# 113315   10.0  https://web.archive.org/web/20161021132106/htt...
# 34359     5.0                                                NaN
#
#                                                   content
# 61591   Five years of drought,   temperatures and gust...
# 109354
# 64387   Today may be the day when cable and telecom ex...
# 91682        As Iraqi troops slowly push into Mosul ba...
# 96325   , A reader writes: Yesterday morning, after a ...
# 68383    North Korea displayed what appeared to be new...
# 72574    The U. S. Treasury Department is finalizing n...
# 9641    Caitlyn Jenner, formerly known as Bruce Jenner...
# 113315  ’ Hundreds of snow leopards are killed every y...
# 34359    (CNN) A gay man is suing a funeral home in Mi...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142570 entries, 0 to 142569
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           142570 non-null  int64
#  1   title        142568 non-null  object
#  2   publication  142570 non-null  object
#  3   author       126694 non-null  object
#  4   date         139929 non-null  object
#  5   year         139929 non-null  float64
#  6   month        139929 non-null  float64
#  7   url          85559 non-null   object
#  8   content      142570 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 9.8+ MB

# %%
data['title'] = data['title'].fillna('')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142570 entries, 0 to 142569
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           142570 non-null  int64
#  1   title        142570 non-null  object
#  2   publication  142570 non-null  object
#  3   author       126694 non-null  object
#  4   date         139929 non-null  object
#  5   year         139929 non-null  float64
#  6   month        139929 non-null  float64
#  7   url          85559 non-null   object
#  8   content      142570 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 9.8+ MB

# %%
clinton_data = data[(data['year'] == 2016) &
                    (data['title'].str.contains('Clinton'))]
clinton_data.sample(20)
# Out:
#             id                                              title  \
# 112441  109027   Clinton Campaign Expands Latino Operation To ...
# 62625   171461  New Emails Raise Questions About Ties Between ...
# 111240  104724   Defeated In New Hampshire, Clinton Camp Alrea...
# 72490   188203  Sanders, Clinton join picket lines, fight for ...
# 27320    46082  AP: Bill Clinton Defends Scandal-Plagued Clint...
# 111576  105896   Clinton Apologizes For Praising The Reagans’ ...
# 46121    68569       Hillary Clinton projected to win Mississippi
# 29229    48001  Mook Dodges on Clinton’s Syria Policy, MSNBC P...
# 18740    37483  Joan Walsh: Bill’s Past Accusations Could ’Hur...
# 19490    38235  ‘I’m Not Commenting’ - Hillary Clinton Refuses...
# 86522   210406  Clinton is running for president. Sanders is d...
# 47225    69997  ’You’re going to find it very, very interestin...
# 22639    41390  Hillary Clinton: New York Gun Crime Driven by ...
# 38401    58566  Michelle Obama: The Clinton surrogate that cou...
# 37276    57214          Quinnipiac poll: Clinton leads Trump by 7
# 91342   216477  Biden says ‘battered’ Clinton must be ‘more op...
# 96995    79238  ‘Low-Key, Loyal Effectiveness’: Clinton Choose...
# 37636    57645        What we know about Hillary Clinton’s health
# 101577   84863  Clinton’s State Dept. calendar missing scores ...
# 81370   203826  Hillary Clinton’s loss in Michigan, explained ...
#
#              publication                            author        date  \
# 112441     Buzzfeed News               Adrian Carrasquillo  2016-07-08
# 62625                NPR                   Brakkton Booker  2016-08-10
# 111240     Buzzfeed News                       Ruby Cramer  2016-02-11
# 72490            Reuters  Gina Cherelus and Megan Cassella  2016-04-14
# 27320          Breitbart                    Breitbart News  2016-08-24
# 111576     Buzzfeed News                     Chris Geidner  2016-03-12
# 46121   Business Insider                      Maxwell Tani  2016-03-09
# 29229          Breitbart                      Ian Hanchett  2016-09-21
# 18740          Breitbart                      Ian Hanchett  2016-01-08
# 19490          Breitbart                  Charlie Spiering  2016-04-18
# 86522    Washington Post                 Stephen Stromberg  2016-03-07
# 47225   Business Insider                       Allan Smith  2016-06-08
# 22639          Breitbart                       AWR Hawkins  2016-04-07
# 38401                CNN                      Kevin Liptak  2016-10-13
# 37276                CNN                               NaN  2016-08-25
# 91342    Washington Post                     Elise Viebeck  2016-10-30
# 96995           Atlantic                        Nora Kelly  2016-07-22
# 37636                CNN                               NaN  2016-09-11
# 101577          Fox News                               NaN  2016-06-24
# 81370                Vox                     Yochi Dreazen  2016/12/21
#
#           year  month                                                url  \
# 112441  2016.0    7.0  https://web.archive.org/web/20160708150131/htt...
# 62625   2016.0    8.0  http://www.npr.org/2016/08/10/489462473/new-em...
# 111240  2016.0    2.0  https://web.archive.org/web/20160211092722/htt...
# 72490   2016.0    4.0  http://www.reuters.com/article/us-usa-election...
# 27320   2016.0    8.0                                                NaN
# 111576  2016.0    3.0  https://web.archive.org/web/20160312004644/htt...
# 46121   2016.0    3.0                                                NaN
# 29229   2016.0    9.0                                                NaN
# 18740   2016.0    1.0                                                NaN
# 19490   2016.0    4.0                                                NaN
# 86522   2016.0    3.0  https://web.archive.org/web/20160308003241/htt...
# 47225   2016.0    6.0                                                NaN
# 22639   2016.0    4.0                                                NaN
# 38401   2016.0   10.0                                                NaN
# 37276   2016.0    8.0                                                NaN
# 91342   2016.0   10.0  https://web.archive.org/web/20161031000405/htt...
# 96995   2016.0    7.0                                                NaN
# 37636   2016.0    9.0                                                NaN
# 101577  2016.0    6.0  https://web.archive.org/web/20160626000955/htt...
# 81370   2016.0   12.0  http://www.vox.com/policy-and-politics/2016/12...
#
#                                                   content
# 112441   Faced with an opponent in Donald Trump with h...
# 62625   THIS POST WAS UPDATED AT 4:01 P. M. ET, A fres...
# 111240   MANCHESTER, N. H.  —   Three months ago, on a...
# 72490    Democratic presidential contenders Bernie San...
# 27320   ATLANTA (AP)  —   Former President Bill Clinto...
# 111576   \t\t\tHillary Clinton apologized for her rema...
# 46121   ’Democratic presidential candidate Hillary Cli...
# 29229   On Wednesday’s broadcast of MSNBC’s “Morning J...
# 18740   MSNBC Political Analyst Joan Walsh argued that...
# 19490   Former Secretary of State Hillary Clinton refu...
# 86522          It is amazing how little the Democratic...
# 47225   ’’ ’Donald Trump announced during a   address ...
# 22639   During an April 4 meeting with New York state ...
# 38401    (CNN) Not only has Michelle Obama delivered t...
# 37276    (CNN) Hillary Clinton holds a   edge over Don...
# 91342        Vice President Biden said Hillary Clinton...
# 96995           For us to continue writing great stori...
# 37636    (CNN) As Hillary Clinton fell ill during a   ...
# 101577   An Associated Press review of the official ca...
# 81370    Heading into election night, Michigan was sup...
