# %%
import pandas as pd
import glob

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 50)

# %%
path = './Articles'
files = glob.glob(path+'/*.csv')

li = []

for file in files:
    df = pd.read_csv(file, index_col=None, header=0)
    li.append(df)

data = pd.concat(li, axis=0, ignore_index=True)
data = data.drop(data.columns[0], axis=1)

# %%
data.sample(10)
# Out:
#             id                                              title  \
# 135526  142477         DreamWorks Animation finally finds a buyer
# 31029    49802  DNC Insists Primary/Superdelegates Not ’Rigged...
# 113100  111332   Sacramento Police Tried To Run Over A Homeles...
# 61030   169425  Protesters, Police Clash At Donald Trump Rally...
# 131895  137881  Pensions for felonious pols: An outrage NY law...
# 136868  144354  MLB owners threatening lockout as baseball fea...
# 64136   173314                               Bob Dylan, Revisited
# 101992   85331  Belgium arrests 2 brothers suspected of plotti...
# 70094   184301  Suspect in Michigan airport stabbing attempted...
# 63200   172170  Tiny Laos Readies For A Visit From Obama — And...
#
#           publication                               author        date  \
# 135526  New York Post                      Claire Atkinson  2016-04-28
# 31029       Breitbart                             Tony Lee  2016-02-15
# 113100  Buzzfeed News                      Tamerra Griffin  2016-10-02
# 61030             NPR                    Marie Andrusewicz  2016-05-25
# 131895  New York Post                 Post Editorial Board  2016-04-30
# 136868  New York Post                         Joel Sherman  2016-11-22
# 64136             NPR                  Anastasia Tsioulcas  2016-10-13
# 101992       Fox News                                  NaN  2016-07-30
# 70094         Reuters  Timothy Mclaughlin and Julia Jacobs  2017-06-22
# 63200             NPR                             Elise Hu  2016-09-04
#
#           year  month                                                url  \
# 135526  2016.0    4.0  http://nypost.com/2016/04/28/dreamworks-finall...
# 31029   2016.0    2.0                                                NaN
# 113100  2016.0   10.0  https://web.archive.org/web/20161002041951/htt...
# 61030   2016.0    5.0  http://www.npr.org/sections/thetwo-way/2016/05...
# 131895  2016.0    4.0  http://nypost.com/2016/04/30/pensions-for-felo...
# 136868  2016.0   11.0  http://nypost.com/2016/11/22/mlb-owners-threat...
# 64136   2016.0   10.0  http://www.npr.org/sections/therecord/2016/10/...
# 101992  2016.0    7.0  https://web.archive.org/web/20160731013233/htt...
# 70094   2017.0    6.0  http://www.reuters.com/article/us-michigan-air...
# 63200   2016.0    9.0  http://www.npr.org/sections/parallels/2016/09/...
#
#                                                   content
# 135526  The third time’s the charm for studio chieftai...
# 31029   The Democratic National Committee is insisting...
# 113100  ’Recently released dash cam footage shows two ...
# 61030   The scene outside a Donald Trump campaign rall...
# 131895  Dean Skelos’ lawyers last week protested the p...
# 136868  Since the cancellation of the 1994 World Serie...
# 64136   It’s tough to think of a major honor that hasn...
# 101992  Nourredine H. 33, and his brother Hamza H. wer...
# 70094   The suspect, Amor Ftouhi, 49, of Quebec, Canad...
# 63200   The shops here in Vientiane, the capital of La...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142570 entries, 0 to 142569
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           142570 non-null  int64
#  1   title        142568 non-null  object
#  2   publication  142570 non-null  object
#  3   author       126694 non-null  object
#  4   date         139929 non-null  object
#  5   year         139929 non-null  float64
#  6   month        139929 non-null  float64
#  7   url          85559 non-null   object
#  8   content      142570 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 9.8+ MB

# %%
data['title'] = data['title'].fillna('')

# %%
clinton_data = data[(data['year'] == 2016) &
                    (data['title'].str.contains('Hillary Clinton'))]
clinton_data = clinton_data[(clinton_data['publication'] == 'Washington Post') | 
                            (clinton_data['publication'] == 'New York Times')]
clinton_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 329 entries, 2614 to 92416
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           329 non-null    int64
#  1   title        329 non-null    object
#  2   publication  329 non-null    object
#  3   author       327 non-null    object
#  4   date         329 non-null    object
#  5   year         329 non-null    float64
#  6   month        329 non-null    float64
#  7   url          175 non-null    object
#  8   content      329 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 25.7+ KB

# %%
pd.set_option('display.max_colwidth', 500)
clinton_data[['title', 'publication', 'author']].sample(5).reset_index()
# Out:
#    index  \
# 0  88759
# 1  90940
# 2   2692
# 3   3048
# 4  89959
#
#                                                                                                      title  \
# 0                                         Does Hillary Clinton really need Elizabeth Warren on the ticket?
# 1                                          The facts about Hillary Clinton and the Kathy Shelton rape case
# 2  Yes, It’s Early, but Donald Trump Would Have Uphill Battle Against Hillary Clinton - The New York Times
# 3         Hillary Clinton’s Message: Yes, the Economy Is Messed Up. But I Can Fix It. - The New York Times
# 4           ‘Dr. Drew’ show canceled days after host’s negative speculation about Hillary Clinton’s health
#
#        publication         author
# 0  Washington Post    John Wagner
# 1  Washington Post  Glenn Kessler
# 2   New York Times      Nate Cohn
# 3   New York Times     Neil Irwin
# 4  Washington Post   Fred Barbash

# %%
pd.set_option('display.max_colwidth', 50)

# %%
clinton_data_1 = clinton_data[0:110]
clinton_data_2 = clinton_data[110:220]
clinton_data_3 = clinton_data[220:]

# %%
clinton_data_1.to_csv('clinton_data_1.csv', index=False)
clinton_data_2.to_csv('clinton_data_2.csv', index=False)
clinton_data_3.to_csv('clinton_data_3.csv', index=False)

# %%
li = []
clinton_data_1_gender = pd.read_csv('clinton_data_1_gender.csv', index_col=None, header=0)
clinton_data_2_gender = pd.read_csv('clinton_data_2_gender.csv', index_col=None, header=0)
clinton_data_3_gender = pd.read_csv('clinton_data_3_gender.csv', index_col=None, header=0)
li.append(clinton_data_1_gender)
li.append(clinton_data_2_gender)
li.append(clinton_data_3_gender)

clinton_data_gender = pd.concat(li, axis=0, ignore_index=True)

# %%
clinton_data_gender.sample(5)
# Out:
#          id                                              title  \
# 210  211893  Hillary Clinton: A woman and candidate with se...
# 24    20551  Bernie Sanders Refuses to Concede Nomination t...
# 51    21534  Hillary Clinton, Donald Trump, Mother Teresa: ...
# 310  216254  Here’s what happens when Miley Cyrus door knoc...
# 303  215975  Did WikiLeaks make Hillary Clinton look two-fa...
#
#          publication                                 author gender  \
# 210  Washington Post                            Janell Ross      F
# 24    New York Times                       Yamiche Alcindor      F
# 51    New York Times  Andrea Kannapell and Sandra Stevenson      F
# 310  Washington Post                            Ian Shapira      M
# 303  Washington Post                           Charles Lane      M
#
#            date    year  month  \
# 210  2016-05-11  2016.0    5.0
# 24   2016-06-13  2016.0    6.0
# 51   2016-09-03  2016.0    9.0
# 310  2016-10-22  2016.0   10.0
# 303  2016-10-12  2016.0   10.0
#
#                                                    url  \
# 210  https://web.archive.org/web/20160512002755/htt...
# 24                                                 NaN
# 51                                                 NaN
# 310  https://web.archive.org/web/20161023002659/htt...
# 303  https://web.archive.org/web/20161013005231/htt...
#
#                                                content
# 210         On Monday, Republican presidential cand...
# 24   Senator Bernie Sanders said on Sunday that he ...
# 51   (Want to get this briefing by email? Here’s th...
# 310  Miley Cyrus  —   the celebrity wrecking ball, ...
# 303  Of all the   in the   WikiLeaks release of hac...

# %%
clinton_data_gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           329 non-null    int64
#  1   title        329 non-null    object
#  2   publication  329 non-null    object
#  3   author       328 non-null    object
#  4   gender       329 non-null    object
#  5   date         329 non-null    object
#  6   year         329 non-null    float64
#  7   month        329 non-null    float64
#  8   url          175 non-null    object
#  9   content      329 non-null    object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 25.8+ KB

# %%
clinton_data_gender['gender'].value_counts()
# Out:
# M    185
# F    101
# B     43
# Name: gender, dtype: int64

# %%
clinton_data_gender.to_csv('clinton_data_gender.csv', index=False)
