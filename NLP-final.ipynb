# %%
import pandas as pd
import glob

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
path = './Articles'
files = glob.glob(path+'/*.csv')

li = []

for file in files:
    df = pd.read_csv(file, index_col=None, header=0)
    li.append(df)

data = pd.concat(li, axis=0, ignore_index=True)
data = data.drop(data.columns[0], axis=1)

# %%
data.sample(10)
# Out:
#             id                                              title  \
# 103190   86678  Email scandal proves Hillary learned wrong les...
# 8752     27488  Report: Trump Moves to Own Tax Reform Plan Wit...
# 71584   186789  U.S. court test on abortion reflects success o...
# 131533  137443  FTC rejects Sherwin-Williams’ concessions in V...
# 54776   161843  Health Insurers Face ’Massive Confusion’ As GO...
# 118035  119603                        Obama: Whose Side Is He On?
# 120892  123209        Buzzfeed just did Donald Trump a huge favor
# 87466   211594  The bombing of an Aleppo hospital should spur ...
# 130457  136236  The reason Stephen A. Smith is happy Skip Bayl...
# 85320   208838  One reason the GOP health bill is a mess: No o...
#
#             publication           author        date    year  month  \
# 103190         Fox News    K T McFarland  2016-10-31  2016.0   10.0
# 8752          Breitbart   Neil W. McCabe  2017-04-03  2017.0    4.0
# 71584           Reuters    Joan Biskupic  2016-02-28  2016.0    2.0
# 131533    New York Post      Josh Kosman  2016-10-28  2016.0   10.0
# 54776               NPR      Jay Hancock  2017-02-09  2017.0    2.0
# 118035  National Review      Mona Charen  2016-06-14  2016.0    6.0
# 120892    New York Post       Rich Lowry  2017-01-12  2017.0    1.0
# 87466   Washington Post  Editorial Board  2016-04-29  2016.0    4.0
# 130457    New York Post  Mark W. Sanchez  2016-07-25  2016.0    7.0
# 85320   Washington Post        Paul Kane  2017-07-06  2017.0    7.0
#
#                                                       url  \
# 103190  https://web.archive.org/web/20161101010355/htt...
# 8752                                                  NaN
# 71584   http://www.reuters.com/article/us-usa-court-ab...
# 131533  http://nypost.com/2016/10/28/ftc-rejects-sherw...
# 54776   http://www.npr.org/sections/health-shots/2017/...
# 118035  http://www.nationalreview.com/article/436626/o...
# 120892  https://web.archive.org/web/20170114003158/htt...
# 87466   https://web.archive.org/web/20160430005138/htt...
# 130457  http://nypost.com/2016/07/25/the-reason-stephe...
# 85320   https://web.archive.org/web/20170707000018/htt...
#
#                                                   content
# 103190  Her job? Investigating President Nixon’s invol...
# 8752    Politico reported Thursday that President Dona...
# 71584    When the U. S. Supreme Court on Wednesday hea...
# 131533  President Obama’s Federal Trade Commission is ...
# 54776   Premiums for Obamacare plans sold by New Mexic...
# 118035  Whole doctoral dissertations could be devoted ...
# 120892  The best thing that happened to Donald Trump a...
# 87466    THE DEVASTATING bombing of an Aleppo hospital...
# 130457  “First Take” is dead. Long live “First Take. ”...
# 85320    Sen. Patrick J. Toomey offered a simple, rema...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142570 entries, 0 to 142569
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           142570 non-null  int64
#  1   title        142568 non-null  object
#  2   publication  142570 non-null  object
#  3   author       126694 non-null  object
#  4   date         139929 non-null  object
#  5   year         139929 non-null  float64
#  6   month        139929 non-null  float64
#  7   url          85559 non-null   object
#  8   content      142570 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 9.8+ MB
